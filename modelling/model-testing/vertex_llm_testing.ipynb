# %%
from djangoapp.news.vertex.cloud.connections_based_on_docs import VertexAI

# %%
llm = VertexAI()


import pickle
import pandas as pd
# import data from pickle
df = pd.read_csv('../data/merged_titles_labels.csv')
df.head()
# Out:
#                                                title  is_clickbait
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...             1
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...             0
# 2                  Why the Truth Might Get You Fired             1
# 3  15 Civilians Killed In Single US Airstrike Hav...             1
# 4  Iranian woman jailed for fictional unpublished...             1

# %%
# select 2500 random samples - 1250 from each class
import random
n_samples = 1000
random.seed(42)
df = df.sample(frac=1).reset_index(drop=True)
df = df.groupby('is_clickbait').head(n_samples//2)
df = df.sample(frac=1).reset_index(drop=True)
df.is_clickbait.value_counts()
# Out:
# is_clickbait
# 0    500
# 1    500
# Name: count, dtype: int64

# %%
df['llm_pred'] = None
df
# Out:
#                                                  title  is_clickbait llm_pred
# 0                     Earthquake shakes western Mexico             0     None
# 1    Brandon Marshall receives threatening letter; ...             0     None
# 2    Visa Ban Amended to Allow Iraqi Interpreters I...             0     None
# 3    Star Wars: What do fans make of the trailer fo...             1     None
# 4          61 businesses Trump has targeted on Twitter             1     None
# ..                                                 ...           ...      ...
# 995  Workplace reform campaign most expensive in Au...             0     None
# 996  US Secret Service Struggles To Find Recruits W...             1     None
# 997   Time to Unravel the Knot of Credit-Default Swaps             0     None
# 998  Which "Shameless" Character Are You Based On Y...             1     None
# 999  [WATCH] 13-Year-Old Girl BREAKS THE INTERNET W...             1     None
#
# [1000 rows x 3 columns]

# %%
from tqdm.auto import tqdm
import numpy as np
preds = np.array([])
for i in tqdm(range(0, n_samples)):
    try:
        print(df.iloc[i]['title'])
        pred = llm.run(title=df.iloc[i]['title'])
        preds = np.append(preds, pred)
    except:
        print("error when running LLM")
        preds = np.append(preds, np.nan)
        
    print("")
preds    
df['llm_pred'] = preds
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Earthquake shakes western Mexico
# Prediction: 0 for prompt: Is this title a clickbait: 'Earthquake shakes western Mexico'? Return 1 if yes, 0 if no.
# Return value: False
#
# Brandon Marshall receives threatening letter; Broncos investigating
# Prediction: 1 for prompt: Is this title a clickbait: 'Brandon Marshall receives threatening letter; Broncos investigating'? Return 1 if yes, 0 if no.
# Return value: True
#
# Visa Ban Amended to Allow Iraqi Interpreters Into U.S.
# Prediction: 0 for prompt: Is this title a clickbait: 'Visa Ban Amended to Allow Iraqi Interpreters Into U.S. '? Return 1 if yes, 0 if no.
# Return value: False
#
# Star Wars: What do fans make of the trailer for The Last Jedi?
# Prediction: 1 for prompt: Is this title a clickbait: 'Star Wars: What do fans make of the trailer for The Last Jedi?'? Return 1 if yes, 0 if no.
# Return value: True
#
# 61 businesses Trump has targeted on Twitter
# Prediction: 1 for prompt: Is this title a clickbait: '61 businesses Trump has targeted on Twitter'? Return 1 if yes, 0 if no.
# Return value: True
#
# Cara Delevingne Has Opened Up About Her Struggle With Mental Illness
# Prediction: 0 for prompt: Is this title a clickbait: 'Cara Delevingne Has Opened Up About Her Struggle With Mental Illness'? Return 1 if yes, 0 if no.
# Return value: False
#
# Stop Bleeding in 10 Seconds With Cayenne Pepper
# error when running LLM
#
# Opposition Leader predicts 'people's revolt' in Australia over carbon tax
# Prediction: 1 for prompt: Is this title a clickbait: 'Opposition Leader predicts 'people's revolt' in Australia over carbon tax'? Return 1 if yes, 0 if no.
# Return value: True
#
# Tell Us About Your Self(ie): Alli Simpson
# Prediction: 1 for prompt: Is this title a clickbait: 'Tell Us About Your Self(ie): Alli Simpson'? Return 1 if yes, 0 if no.
# Return value: True
#
# Here's What Top Professional Models Look Like Without Makeup
# Prediction: 1 for prompt: Is this title a clickbait: 'Here's What Top Professional Models Look Like Without Makeup'? Return 1 if yes, 0 if no.
# Return value: True
#
# David Cameron orders crackdown on summer surge of FGM cases
# Prediction: 1 for prompt: Is this title a clickbait: 'David Cameron orders crackdown on summer surge of FGM cases'? Return 1 if yes, 0 if no.
# Return value: True
#
# Dear Azzy: Soros and Sluts
# error when running LLM
#
# BREAKING – Obama Betrays America in MASSIVE Move Before He Leaves Office, Media is Silent | EndingFed News Network
# Prediction: 1 for prompt: Is this title a clickbait: 'BREAKING – Obama Betrays America in MASSIVE Move Before He Leaves Office, Media is Silent | EndingFed News Network'? Return 1 if yes, 0 if no.
# Return value: True
#
# Immigrants Who Came to U.S. as Children Fear Deportation Under Trump - The New York Times
# Prediction: 0 for prompt: Is this title a clickbait: 'Immigrants Who Came to U.S. as Children Fear Deportation Under Trump - The New York Times'? Return 1 if yes, 0 if no.
# Return value: False
#
# Which Young Adult Heroine Are You Based On Your Zodiac Sign
# Prediction: 1 for prompt: Is this title a clickbait: 'Which Young Adult Heroine Are You Based On Your Zodiac Sign'? Return 1 if yes, 0 if no.
# Return value: True
#
# We Know Which Celebrity You Hate The Most
# Prediction: 1 for prompt: Is this title a clickbait: 'We Know Which Celebrity You Hate The Most'? Return 1 if yes, 0 if no.
# Return value: True
#
# We Tested Four Long-Wear Lipsticks To See Which One Lasted The Longest
# Prediction: 1 for prompt: Is this title a clickbait: 'We Tested Four Long-Wear Lipsticks To See Which One Lasted The Longest'? Return 1 if yes, 0 if no.
# Return value: True
#
# Keith Broomfield, American Slain Fighting ISIS, ‘Knew the Risk’
# Prediction: 1 for prompt: Is this title a clickbait: 'Keith Broomfield, American Slain Fighting ISIS, ‘Knew the Risk’'? Return 1 if yes, 0 if no.
# Return value: True
#
# 25 Insanely Fun Kitchen Tools You Need Immediately
# Prediction: 1 for prompt: Is this title a clickbait: '25 Insanely Fun Kitchen Tools You Need Immediately'? Return 1 if yes, 0 if no.
# Return value: True
#
# EU leader declares Trump a "threat" to European Union
# Prediction: 1 for prompt: Is this title a clickbait: 'EU leader declares Trump a "threat" to European Union'? Return 1 if yes, 0 if no.
# Return value: True
#
# Palmer Luckey: Trump-supporting Oculus founder leaves Facebook
# Prediction: 1 for prompt: Is this title a clickbait: 'Palmer Luckey: Trump-supporting Oculus founder leaves Facebook'? Return 1 if yes, 0 if no.
# Return value: True
#
# 'After pushing him off three times I broke his nose': Women who have been sexually assaulted in public reveal how they fought back (while some were terrified into silence)
# error when running LLM
#
# SAG Leader, in Shift, No Longer Seeks Strike Vote
# Prediction: 0 for prompt: Is this title a clickbait: 'SAG Leader, in Shift, No Longer Seeks Strike Vote'? Return 1 if yes, 0 if no.
# Return value: False
#
# This Is Julia, Sesame Street's First Character With Autism
# Prediction: 0 for prompt: Is this title a clickbait: 'This Is Julia, Sesame Street's First Character With Autism'? Return 1 if yes, 0 if no.
# Return value: False
#
# Obama Telephones Afghan President
# Prediction: 0 for prompt: Is this title a clickbait: 'Obama Telephones Afghan President'? Return 1 if yes, 0 if no.
# Return value: False
#
# 787 Dreamliner has eyepopping rehearsal for Paris Air Show
# Prediction: 1 for prompt: Is this title a clickbait: '787 Dreamliner has eyepopping rehearsal for Paris Air Show'? Return 1 if yes, 0 if no.
# Return value: True
#
# 22 Pictures That Are Way Too Real For Risk Players
# Prediction: 1 for prompt: Is this title a clickbait: '22 Pictures That Are Way Too Real For Risk Players'? Return 1 if yes, 0 if no.
# Return value: True
#
# Yasiin Bey Has Three Albums on the Way Including a Joint Project With Mannie Fresh
# Prediction: 0 for prompt: Is this title a clickbait: 'Yasiin Bey Has Three Albums on the Way Including a Joint Project With Mannie Fresh'? Return 1 if yes, 0 if no.
# Return value: False
#
# What is Donald Trump doing for Christmas?
# Prediction: 1 for prompt: Is this title a clickbait: 'What is Donald Trump doing for Christmas?'? Return 1 if yes, 0 if no.
# Return value: True
#
# Pentatonix's 'Christmas' Album Spends Second Week at No. 1 on Billboard 200
# Prediction: 0 for prompt: Is this title a clickbait: 'Pentatonix's 'Christmas' Album Spends Second Week at No. 1 on Billboard 200'? Return 1 if yes, 0 if no.
# Return value: False
#
# We Know What Kind Of Man Will Get You Off
# Prediction: 1 for prompt: Is this title a clickbait: 'We Know What Kind Of Man Will Get You Off'? Return 1 if yes, 0 if no.
# Return value: True
#
# 13 Reasons Life Would Be Better In Halloweentown
# Prediction: 1 for prompt: Is this title a clickbait: '13 Reasons Life Would Be Better In Halloweentown'? Return 1 if yes, 0 if no.
# Return value: True
#
# Priest Stabbed After Opening His Home To ’Asylum Seeker’ Who Claimed To Be In Need
# Prediction: 1 for prompt: Is this title a clickbait: 'Priest Stabbed After Opening His Home To ’Asylum Seeker’ Who Claimed To Be In Need'? Return 1 if yes, 0 if no.
# Return value: True
#
# After Prodding, Republicans Slowing Down Cabinet Confirmation Process
# Prediction: 1 for prompt: Is this title a clickbait: 'After Prodding, Republicans Slowing Down Cabinet Confirmation Process'? Return 1 if yes, 0 if no.
# Return value: True
#
# British Airways give medals to Flight 38's crew
# Prediction: 0 for prompt: Is this title a clickbait: 'British Airways give medals to Flight 38's crew'? Return 1 if yes, 0 if no.
# Return value: False
#
# MSNBC’s Nance: Trump Has ’Always Promised Autocracy,’ He’s ’Closest Thing We’ve Ever Had to King George III’ - Breitbart
# Prediction: 1 for prompt: Is this title a clickbait: 'MSNBC’s Nance: Trump Has ’Always Promised Autocracy,’ He’s ’Closest Thing We’ve Ever Had to King George III’ - Breitbart'? Return 1 if yes, 0 if no.
# Return value: True
#
# Heseltine strangled dog as part of Thatcher cabinet initiation ceremony
# Prediction: 1 for prompt: Is this title a clickbait: 'Heseltine strangled dog as part of Thatcher cabinet initiation ceremony'? Return 1 if yes, 0 if no.
# Return value: True
#
# 39 Songs You Need In Your Life This January
# Prediction: 1 for prompt: Is this title a clickbait: '39 Songs You Need In Your Life This January'? Return 1 if yes, 0 if no.
# Return value: True
#
# Michael Moore Just Brought Every Liberal To Their Knees With This Epic Rant Proving Trump Will Win, Michael Moore Admits He Is Right
# Prediction: 1 for prompt: Is this title a clickbait: 'Michael Moore Just Brought Every Liberal To Their Knees With This Epic Rant Proving Trump Will Win, Michael Moore Admits He Is Right'? Return 1 if yes, 0 if no.
# Return value: True
#
# Thanks to Her 'Love Story,' Gwen Stefani Is the New Face of Revlon
# Prediction: 1 for prompt: Is this title a clickbait: 'Thanks to Her 'Love Story,' Gwen Stefani Is the New Face of Revlon'? Return 1 if yes, 0 if no.
# Return value: True
#
# '90s Kids Recreate Their Childhood Halloween Costumes
# Prediction: 1 for prompt: Is this title a clickbait: ''90s Kids Recreate Their Childhood Halloween Costumes'? Return 1 if yes, 0 if no.
# Return value: True
#
# How Income Disparity Impacts Romantic Relationships
# Prediction: 0 for prompt: Is this title a clickbait: 'How Income Disparity Impacts Romantic Relationships'? Return 1 if yes, 0 if no.
# Return value: False
#
# Tim Russert, NBC News "Meet the Press" moderator dies at age 58
# Prediction: 0 for prompt: Is this title a clickbait: 'Tim Russert, NBC News "Meet the Press" moderator dies at age 58'? Return 1 if yes, 0 if no.
# Return value: False
#
# US strikes on Syria: Xi Jinping told Donald Trump he understood the US response 'because of the death of children'
# Prediction: 1 for prompt: Is this title a clickbait: 'US strikes on Syria: Xi Jinping told Donald Trump he understood the US response 'because of the death of children''? Return 1 if yes, 0 if no.
# Return value: True
#
# This Librarian Decorated The Cupboard Under Her Stairs To Look Like "Harry Potter"
# Prediction: 1 for prompt: Is this title a clickbait: 'This Librarian Decorated The Cupboard Under Her Stairs To Look Like "Harry Potter"'? Return 1 if yes, 0 if no.
# Return value: True
#
# How Much Do You Actually Love "Hamilton"
# Prediction: 1 for prompt: Is this title a clickbait: 'How Much Do You Actually Love "Hamilton"'? Return 1 if yes, 0 if no.
# Return value: True
#
# 27 Totally Hilarious Family Photos
# Prediction: 1 for prompt: Is this title a clickbait: '27 Totally Hilarious Family Photos'? Return 1 if yes, 0 if no.
# Return value: True
#
# This Is The Best Shah Rukh Khan Tribute Video You'll See All Day
# Prediction: 1 for prompt: Is this title a clickbait: 'This Is The Best Shah Rukh Khan Tribute Video You'll See All Day'? Return 1 if yes, 0 if no.
# Return value: True
#
# Missing woman's relatives find missing man's body in Missouri
# Prediction: 1 for prompt: Is this title a clickbait: 'Missing woman's relatives find missing man's body in Missouri '? Return 1 if yes, 0 if no.
# Return value: True
#
# Russia Facing Long Recession, World Bank Says
# Prediction: 1 for prompt: Is this title a clickbait: 'Russia Facing Long Recession, World Bank Says'? Return 1 if yes, 0 if no.
# Return value: True
#
# 19 Stunningly Weird Pieces Of Anatomy Jewelry
# Prediction: 1 for prompt: Is this title a clickbait: '19 Stunningly Weird Pieces Of Anatomy Jewelry'? Return 1 if yes, 0 if no.
# Return value: True
#
# 15 Things People Who Talk To Themselves Will Understand
# Prediction: 1 for prompt: Is this title a clickbait: '15 Things People Who Talk To Themselves Will Understand'? Return 1 if yes, 0 if no.
# Return value: True
#
# Fox News Calls for Special Prosecutor to Investigate Hillary Clinton
# Prediction: 1 for prompt: Is this title a clickbait: 'Fox News Calls for Special Prosecutor to Investigate Hillary Clinton'? Return 1 if yes, 0 if no.
# Return value: True
#
# In a Smoky Haze, Turks Cling to Their Cigarettes - The New York Times
# Prediction: 1 for prompt: Is this title a clickbait: 'In a Smoky Haze, Turks Cling to Their Cigarettes - The New York Times'? Return 1 if yes, 0 if no.
# Return value: True
#
# 28 Tweets That Sum Up What It's Like To Grow Up In New Jersey
# Prediction: 1 for prompt: Is this title a clickbait: '28 Tweets That Sum Up What It's Like To Grow Up In New Jersey'? Return 1 if yes, 0 if no.
# Return value: True
#
# Tyco executives found guilty
# Prediction: 0 for prompt: Is this title a clickbait: 'Tyco executives found guilty'? Return 1 if yes, 0 if no.
# Return value: False
#
# Mayor of Camden, London, arrested in benefit fraud inquiry
# Prediction: 1 for prompt: Is this title a clickbait: 'Mayor of Camden, London, arrested in benefit fraud inquiry'? Return 1 if yes, 0 if no.
# Return value: True
#
# Nelson Mandela suffers collapsed lung
# Prediction: 1 for prompt: Is this title a clickbait: 'Nelson Mandela suffers collapsed lung'? Return 1 if yes, 0 if no.
# Return value: True
#
# National Weather Service accused of knowingly misleading public
# Prediction: 1 for prompt: Is this title a clickbait: 'National Weather Service accused of knowingly misleading public'? Return 1 if yes, 0 if no.
# Return value: True
#
# Corruption Scandals With Brazilian Roots Cascade Across Latin America - The New York Times
# Prediction: 0 for prompt: Is this title a clickbait: 'Corruption Scandals With Brazilian Roots Cascade Across Latin America - The New York Times'? Return 1 if yes, 0 if no.
# Return value: False
#
# US to host North Korean diplomat for nuclear talks
# Prediction: 0 for prompt: Is this title a clickbait: 'US to host North Korean diplomat for nuclear talks'? Return 1 if yes, 0 if no.
# Return value: False
#
# Bruney Looks to Explain Continued Elbow Pain
# Prediction: 1 for prompt: Is this title a clickbait: 'Bruney Looks to Explain Continued Elbow Pain'? Return 1 if yes, 0 if no.
# Return value: True
#
# BBC’s Children Show ‘Just a Girl’ is About a Transgender Child Taking Hormone Blocking Drugs
# Prediction: 1 for prompt: Is this title a clickbait: 'BBC’s Children Show ‘Just a Girl’ is About a Transgender Child Taking Hormone Blocking Drugs'? Return 1 if yes, 0 if no.
# Return value: True
#
# Make Cinnamon Donut Holes At Home Like A Pro
# Prediction: 1 for prompt: Is this title a clickbait: 'Make Cinnamon Donut Holes At Home Like A Pro'? Return 1 if yes, 0 if no.
# Return value: True
#
# Orlando Manhunt: Two Officers Die in Pursuit of Murder Suspect
# Prediction: 1 for prompt: Is this title a clickbait: 'Orlando Manhunt: Two Officers Die in Pursuit of Murder Suspect'? Return 1 if yes, 0 if no.
# Return value: True
#
# Hillary and Bill Clinton: The «Bonnie and Clyde» of American Politics
# Prediction: 1 for prompt: Is this title a clickbait: 'Hillary and Bill Clinton: The «Bonnie and Clyde» of American Politics'? Return 1 if yes, 0 if no.
# Return value: True
#
# Ron Paul to Trump: Don't Listen to Neocons!
# Prediction: 1 for prompt: Is this title a clickbait: 'Ron Paul to Trump: Don't Listen to Neocons!'? Return 1 if yes, 0 if no.
# Return value: True
#
# What Should You Watch On Netflix This October
# Prediction: 1 for prompt: Is this title a clickbait: 'What Should You Watch On Netflix This October'? Return 1 if yes, 0 if no.
# Return value: True
#
# No, There Won't Be A "Game Of Thrones" Movie Any Time Soon
# Prediction: 0 for prompt: Is this title a clickbait: 'No, There Won't Be A "Game Of Thrones" Movie Any Time Soon'? Return 1 if yes, 0 if no.
# Return value: False
#
# America’s Streets Will Run Red With Blood- Mike Adams
# Prediction: 1 for prompt: Is this title a clickbait: 'America’s Streets Will Run Red With Blood- Mike Adams'? Return 1 if yes, 0 if no.
# Return value: True
#
# Elite US colleges have more students from the top 1% than from the bottom 50%
# Prediction: 1 for prompt: Is this title a clickbait: 'Elite US colleges have more students from the top 1% than from the bottom 50%'? Return 1 if yes, 0 if no.
# Return value: True
#
# How Well Do You Actually Know The Lyrics To "Bidi Bidi Bom Bom"
# Prediction: 1 for prompt: Is this title a clickbait: 'How Well Do You Actually Know The Lyrics To "Bidi Bidi Bom Bom"'? Return 1 if yes, 0 if no.
# Return value: True
#
# ISRO's Record Breaking Satellite Launch, Jayalalithaa's Assets To Be Seized And Other Must Read Stories
# Prediction: 1 for prompt: Is this title a clickbait: 'ISRO's Record Breaking Satellite Launch, Jayalalithaa's Assets To Be Seized And Other Must Read Stories'? Return 1 if yes, 0 if no.
# Return value: True
#
# Dueling Discount Patriotism: Choose Your T-Shirt
# Prediction: 1 for prompt: Is this title a clickbait: 'Dueling Discount Patriotism: Choose Your T-Shirt'? Return 1 if yes, 0 if no.
# Return value: True
#
# US Airstrike Kills Four Iraqi Troops Near Mosul
# Prediction: 1 for prompt: Is this title a clickbait: 'US Airstrike Kills Four Iraqi Troops Near Mosul'? Return 1 if yes, 0 if no.
# Return value: True
#
# Community Episode 1: Ladders [Video]
# Prediction: 0 for prompt: Is this title a clickbait: 'Community Episode 1: Ladders [Video]'? Return 1 if yes, 0 if no.
# Return value: False
#
# The "I Think I Hear Your Girlfriend Calling You" Puzzle
# Prediction: 1 for prompt: Is this title a clickbait: 'The "I Think I Hear Your Girlfriend Calling You" Puzzle'? Return 1 if yes, 0 if no.
# Return value: True
#
# Obama’s Crazed DOJ Mandates Police Departments Must Hire Non-Citizens
# Prediction: 1 for prompt: Is this title a clickbait: 'Obama’s Crazed DOJ Mandates Police Departments Must Hire Non-Citizens'? Return 1 if yes, 0 if no.
# Return value: True
#
# Trump May Give the Pentagon More Authority to Conduct Raids - The New York Times
# Prediction: 0 for prompt: Is this title a clickbait: 'Trump May Give the Pentagon More Authority to Conduct Raids - The New York Times'? Return 1 if yes, 0 if no.
# Return value: False
#
# Many Americans Live in ‘Education Deserts,’ New Research Shows
# Prediction: 0 for prompt: Is this title a clickbait: 'Many Americans Live in ‘Education Deserts,’ New Research Shows '? Return 1 if yes, 0 if no.
# Return value: False
#
# If The Muppet Babies Grew Up And Went To Your High School
# Prediction: 1 for prompt: Is this title a clickbait: 'If The Muppet Babies Grew Up And Went To Your High School'? Return 1 if yes, 0 if no.
# Return value: True
#
# Ted Cruz Counts on Army of Volunteers
# Prediction: 1 for prompt: Is this title a clickbait: 'Ted Cruz Counts on Army of Volunteers'? Return 1 if yes, 0 if no.
# Return value: True
#
# Cowboys CB Anthony Brown Gets Tattoo of Potato Chip on Shoulder
# Prediction: 1 for prompt: Is this title a clickbait: 'Cowboys CB Anthony Brown Gets Tattoo of Potato Chip on Shoulder'? Return 1 if yes, 0 if no.
# Return value: True
#
# Working Out the Details of Guns in National Parks
# error when running LLM
#
# Japanese company recalls two million needles in US
# Prediction: 1 for prompt: Is this title a clickbait: 'Japanese company recalls two million needles in US'? Return 1 if yes, 0 if no.
# Return value: True
#
# First contact: Incredible images show lost Amazonian tribe living like their ancestors did 20,000 years ago - and firing SPEARS at photographer in his helicopter
# Prediction: 1 for prompt: Is this title a clickbait: 'First contact: Incredible images show lost Amazonian tribe living like their ancestors did 20,000 years ago - and firing SPEARS at photographer in his helicopter '? Return 1 if yes, 0 if no.
# Return value: True
#
# Un soltero alcanza su primer ochomil de ropa amontonada
# Prediction: 1 for prompt: Is this title a clickbait: 'Un soltero alcanza su primer ochomil de ropa amontonada'? Return 1 if yes, 0 if no.
# Return value: True
#
# 32 Unbelievable Confessions About Masturbation
# error when running LLM
#
# Katie Holmes Talks About Directing, Motherhood and Mistakes - The New York Times
# Prediction: 0 for prompt: Is this title a clickbait: 'Katie Holmes Talks About Directing, Motherhood and Mistakes - The New York Times'? Return 1 if yes, 0 if no.
# Return value: False
#
# Can We Guess Your Age And Gender From This 8-Picture Test
# Prediction: 1 for prompt: Is this title a clickbait: 'Can We Guess Your Age And Gender From This 8-Picture Test'? Return 1 if yes, 0 if no.
# Return value: True
#
# 24 Killed, Mostly Civilians, as Indian, Pakistani Forces Trade Fire in Kashmir
# Prediction: 1 for prompt: Is this title a clickbait: '24 Killed, Mostly Civilians, as Indian, Pakistani Forces Trade Fire in Kashmir'? Return 1 if yes, 0 if no.
# Return value: True
#
# Aaron Gordon Is the Picasso of the Slam Dunk Contest
# Prediction: 1 for prompt: Is this title a clickbait: 'Aaron Gordon Is the Picasso of the Slam Dunk Contest'? Return 1 if yes, 0 if no.
# Return value: True
#
# Selling ‘Regime Change’ Wars to the Masses
# error when running LLM
#
# Mozambique's ruling party retains control in elections
# Prediction: 0 for prompt: Is this title a clickbait: 'Mozambique's ruling party retains control in elections'? Return 1 if yes, 0 if no.
# Return value: False
#
# Serial child imposter held by French police
# Prediction: 1 for prompt: Is this title a clickbait: 'Serial child imposter held by French police'? Return 1 if yes, 0 if no.
# Return value: True
#
# Social-Justice Internet: Chewbacca Mom’s Success Is White Privilege
# Prediction: 1 for prompt: Is this title a clickbait: 'Social-Justice Internet: Chewbacca Mom’s Success Is White Privilege'? Return 1 if yes, 0 if no.
# Return value: True
#
# Where to, Hillary? How Clinton Is Relying on President Obama’s Help - The New York Times
# Prediction: 0 for prompt: Is this title a clickbait: 'Where to, Hillary? How Clinton Is Relying on President Obama’s Help - The New York Times'? Return 1 if yes, 0 if no.
# Return value: False
#
# 26 Priceyish Things You Should Definitely Buy In Your Twenties
# Prediction: 1 for prompt: Is this title a clickbait: '26 Priceyish Things You Should Definitely Buy In Your Twenties'? Return 1 if yes, 0 if no.
# Return value: True
#
# Singer Bjork denounces sexism in pop music industry
# Prediction: 0 for prompt: Is this title a clickbait: 'Singer Bjork denounces sexism in pop music industry'? Return 1 if yes, 0 if no.
# Return value: False
#
# For A-Rod, a New Chapter Will Say Much More Than Words
# Prediction: 1 for prompt: Is this title a clickbait: 'For A-Rod, a New Chapter Will Say Much More Than Words'? Return 1 if yes, 0 if no.
# Return value: True
#
# Thanks to Trump ties, #DeleteUber campaign grows on social media
# Prediction: 1 for prompt: Is this title a clickbait: 'Thanks to Trump ties, #DeleteUber campaign grows on social media'? Return 1 if yes, 0 if no.
# Return value: True
#
# Countries around the world send aid, help to Haiti
# Prediction: 0 for prompt: Is this title a clickbait: 'Countries around the world send aid, help to Haiti'? Return 1 if yes, 0 if no.
# Return value: False
#
# Shaking Pompoms for the Grandfather of Modern Cheerleading
# Prediction: 1 for prompt: Is this title a clickbait: 'Shaking Pompoms for the Grandfather of Modern Cheerleading'? Return 1 if yes, 0 if no.
# Return value: True
#
# Huffington Post: ’Could It Be Time to Deny White Men the Franchise?’
# error when running LLM
#
# Humans season 3 confirmed by Channel 4 and AMC
# Prediction: 0 for prompt: Is this title a clickbait: 'Humans season 3 confirmed by Channel 4 and AMC'? Return 1 if yes, 0 if no.
# Return value: False
#
# Florida grand jury to hear 2013 police shooting of black man holding fake gun
# Prediction: 1 for prompt: Is this title a clickbait: 'Florida grand jury to hear 2013 police shooting of black man holding fake gun'? Return 1 if yes, 0 if no.
# Return value: True
#
# Bill Herz, Last of ‘War of the Worlds’ Broadcast Crew, Dies at 99 - The New York Times
# Prediction: 0 for prompt: Is this title a clickbait: 'Bill Herz, Last of ‘War of the Worlds’ Broadcast Crew, Dies at 99 - The New York Times'? Return 1 if yes, 0 if no.
# Return value: False
#
# In Short Supply in Donald Trump’s Cabinet: Lawyers
# Prediction: 1 for prompt: Is this title a clickbait: 'In Short Supply in Donald Trump’s Cabinet: Lawyers '? Return 1 if yes, 0 if no.
# Return value: True
#
# Providence Jars No. 1 Pittsburgh
# Prediction: 0 for prompt: Is this title a clickbait: 'Providence Jars No. 1 Pittsburgh'? Return 1 if yes, 0 if no.
# Return value: False
#
# Danish and Austrian embassies in Tehran attacked
# Prediction: 1 for prompt: Is this title a clickbait: 'Danish and Austrian embassies in Tehran attacked'? Return 1 if yes, 0 if no.
# Return value: True
#
# Gunman dead after firing on Dallas police outside headquarters
# Prediction: 0 for prompt: Is this title a clickbait: 'Gunman dead after firing on Dallas police outside headquarters '? Return 1 if yes, 0 if no.
# Return value: False
#
# 23 Tweets Every Single Person Can Identify With
# Prediction: 1 for prompt: Is this title a clickbait: '23 Tweets Every Single Person Can Identify With'? Return 1 if yes, 0 if no.
# Return value: True
#
# Kris Jenner Got A Pie In The Face For Not Knowing North West's Middle Name
# Prediction: 1 for prompt: Is this title a clickbait: 'Kris Jenner Got A Pie In The Face For Not Knowing North West's Middle Name'? Return 1 if yes, 0 if no.
# Return value: True
#
# 19 Things Everyone With Naturally Thick Eyebrows Knows To Be True
# Prediction: 1 for prompt: Is this title a clickbait: '19 Things Everyone With Naturally Thick Eyebrows Knows To Be True'? Return 1 if yes, 0 if no.
# Return value: True
#
# Are You More Yuppie Or Hipster
# Prediction: 1 for prompt: Is this title a clickbait: 'Are You More Yuppie Or Hipster'? Return 1 if yes, 0 if no.
# Return value: True
#
# Which "Harry Potter" Movie Should You Watch Right Now
# Prediction: 1 for prompt: Is this title a clickbait: 'Which "Harry Potter" Movie Should You Watch Right Now'? Return 1 if yes, 0 if no.
# Return value: True
#
# Do your homework, Ms. DeVos
# Prediction: 1 for prompt: Is this title a clickbait: 'Do your homework, Ms. DeVos'? Return 1 if yes, 0 if no.
# Return value: True
#
# Sam Smith's Cover Of Drake's "Hotline Bling" Is Everything
# Prediction: 1 for prompt: Is this title a clickbait: 'Sam Smith's Cover Of Drake's "Hotline Bling" Is Everything'? Return 1 if yes, 0 if no.
# Return value: True
#
# Lebanon elects army chief as new president
# Prediction: 0 for prompt: Is this title a clickbait: 'Lebanon elects army chief as new president'? Return 1 if yes, 0 if no.
# Return value: False
#
# How Many Of These 15 Weird Boob Habits Do You Actually Do
# error when running LLM
#
# Comment on Disturbing Body Cam Shows Cop Execute Native American Woman for Holding Haircut Scissors by Ana
# Prediction: 1 for prompt: Is this title a clickbait: 'Comment on Disturbing Body Cam Shows Cop Execute Native American Woman for Holding Haircut Scissors by Ana'? Return 1 if yes, 0 if no.
# Return value: True
#
# Dylan O'Brien's Tweets As Motivational Posters
# Prediction: 1 for prompt: Is this title a clickbait: 'Dylan O'Brien's Tweets As Motivational Posters'? Return 1 if yes, 0 if no.
# Return value: True
#
# McCain: Trump Has No Overall Foreign Policy Strategy - Breitbart
# Prediction: 1 for prompt: Is this title a clickbait: 'McCain: Trump Has No Overall Foreign Policy Strategy - Breitbart'? Return 1 if yes, 0 if no.
# Return value: True
#
# People Are Not Happy With Justin Bieber After He Posted A Picture With Cornrows
# Prediction: 1 for prompt: Is this title a clickbait: 'People Are Not Happy With Justin Bieber After He Posted A Picture With Cornrows'? Return 1 if yes, 0 if no.
# Return value: True
#
# Sean Spicer criticised after saying Adolf Hitler 'didn't use chemical weapons'
# Prediction: 1 for prompt: Is this title a clickbait: 'Sean Spicer criticised after saying Adolf Hitler 'didn't use chemical weapons''? Return 1 if yes, 0 if no.
# Return value: True
#
# 4 Great Books To Read In March
# Prediction: 1 for prompt: Is this title a clickbait: '4 Great Books To Read In March'? Return 1 if yes, 0 if no.
# Return value: True
#
# FBI Wants you to Believe It Examined 650,000 Emails in 691,000 Seconds
# Prediction: 1 for prompt: Is this title a clickbait: 'FBI Wants you to Believe It Examined 650,000 Emails in 691,000 Seconds'? Return 1 if yes, 0 if no.
# Return value: True
#
# WATCH: Cops Rob Every Penny from Family, Including Children For Legal Med. Marijuana Dispensary
# Prediction: 1 for prompt: Is this title a clickbait: 'WATCH: Cops Rob Every Penny from Family, Including Children For Legal Med. Marijuana Dispensary'? Return 1 if yes, 0 if no.
# Return value: True
#
# WHO: Polio reemerging in Africa
# Prediction: 1 for prompt: Is this title a clickbait: 'WHO: Polio reemerging in Africa'? Return 1 if yes, 0 if no.
# Return value: True
#
# Evangelist minister and Islam critic charged with arson in Alabama
# Prediction: 1 for prompt: Is this title a clickbait: 'Evangelist minister and Islam critic charged with arson in Alabama'? Return 1 if yes, 0 if no.
# Return value: True
#
# These Future Applications Of High-Performance Computing Will Make Your Head Spin
# Prediction: 1 for prompt: Is this title a clickbait: 'These Future Applications Of High-Performance Computing Will Make Your Head Spin'? Return 1 if yes, 0 if no.
# Return value: True
#
# Links: 11/2/16
# Prediction: 0 for prompt: Is this title a clickbait: 'Links: 11/2/16'? Return 1 if yes, 0 if no.
# Return value: False
#
# 21 Healthyish Recipes For People Who Can't Live Without Cheese
# Prediction: 1 for prompt: Is this title a clickbait: '21 Healthyish Recipes For People Who Can't Live Without Cheese'? Return 1 if yes, 0 if no.
# Return value: True
#
# Anoymous- The world war 3 will surely happen (29/10/2016) – DOnald trump will win
# Prediction: 1 for prompt: Is this title a clickbait: 'Anoymous- The world war 3 will surely happen (29/10/2016) – DOnald trump will win'? Return 1 if yes, 0 if no.
# Return value: True
#
# New York Times Is Devoting $5 Million More Into Covering Donald Trump
# Prediction: 1 for prompt: Is this title a clickbait: 'New York Times Is Devoting $5 Million More Into Covering Donald Trump'? Return 1 if yes, 0 if no.
# Return value: True
#
# We Tried To Stop Using Exclamation Points And It Was So Hard
# Prediction: 1 for prompt: Is this title a clickbait: 'We Tried To Stop Using Exclamation Points And It Was So Hard'? Return 1 if yes, 0 if no.
# Return value: True
#
# Walt Whitman’s America Through Edward Weston’s Eyes
# Prediction: 1 for prompt: Is this title a clickbait: 'Walt Whitman’s America Through Edward Weston’s Eyes'? Return 1 if yes, 0 if no.
# Return value: True
#
# The First Trailer For "I Am Cait" Season 2 Is Here
# Prediction: 0 for prompt: Is this title a clickbait: 'The First Trailer For "I Am Cait" Season 2 Is Here'? Return 1 if yes, 0 if no.
# Return value: False
#
# Why Chobani Gave Employees A Financial Stake In Company’s Future
# Prediction: 0 for prompt: Is this title a clickbait: 'Why Chobani Gave Employees A Financial Stake In Company’s Future'? Return 1 if yes, 0 if no.
# Return value: False
#
# Neuroscientist Says Fasting Reduces the Risk of Brain Disease But Big Pharma Doesn't Want You to Know | Underground Health
# Prediction: 1 for prompt: Is this title a clickbait: 'Neuroscientist Says Fasting Reduces the Risk of Brain Disease But Big Pharma Doesn't Want You to Know | Underground Health'? Return 1 if yes, 0 if no.
# Return value: True
#
# 13 Insanely Easy 10-Minute Pizza Snacks
# Prediction: 1 for prompt: Is this title a clickbait: '13 Insanely Easy 10-Minute Pizza Snacks'? Return 1 if yes, 0 if no.
# Return value: True
#
# Mike Morell, Cited in ‘Russia Hacking’ Stories, Works for Longtime Clinton Aide Phillippe Reines
# Prediction: 1 for prompt: Is this title a clickbait: 'Mike Morell, Cited in ‘Russia Hacking’ Stories, Works for Longtime Clinton Aide Phillippe Reines'? Return 1 if yes, 0 if no.
# Return value: True
#
# Which One Direction Music Video Is Your Favorite
# Prediction: 1 for prompt: Is this title a clickbait: 'Which One Direction Music Video Is Your Favorite'? Return 1 if yes, 0 if no.
# Return value: True
#
# Melbourne police raid hydroponic cannabis growers
# Prediction: 1 for prompt: Is this title a clickbait: 'Melbourne police raid hydroponic cannabis growers'? Return 1 if yes, 0 if no.
# Return value: True
#
# WSJ: Justice Dept. says Larry Page knew about rogue drug ads
# Prediction: 1 for prompt: Is this title a clickbait: 'WSJ: Justice Dept. says Larry Page knew about rogue drug ads'? Return 1 if yes, 0 if no.
# Return value: True
#
# NYT: Immigration Hard-Liners Rising in Trump Administration - Breitbart
# Prediction: 1 for prompt: Is this title a clickbait: 'NYT: Immigration Hard-Liners Rising in Trump Administration - Breitbart'? Return 1 if yes, 0 if no.
# Return value: True
#
# Facturacion Electronica en Mexico
# Prediction: 0 for prompt: Is this title a clickbait: 'Facturacion Electronica en Mexico'? Return 1 if yes, 0 if no.
# Return value: False
#
# Flynn's access to classified info suspended after resignation
# Prediction: 0 for prompt: Is this title a clickbait: 'Flynn's access to classified info suspended after resignation '? Return 1 if yes, 0 if no.
# Return value: False
#
# On the election of Mr. Trump, by Auslander
# Prediction: 1 for prompt: Is this title a clickbait: 'On the election of Mr. Trump, by Auslander'? Return 1 if yes, 0 if no.
# Return value: True
#
# House Top 40: Flipping Control Still A Tough Task For Democrats
# Prediction: 1 for prompt: Is this title a clickbait: 'House Top 40: Flipping Control Still A Tough Task For Democrats'? Return 1 if yes, 0 if no.
# Return value: True
#
# Floods in South Africa wreak havoc
# Prediction: 0 for prompt: Is this title a clickbait: 'Floods in South Africa wreak havoc'? Return 1 if yes, 0 if no.
# Return value: False
#
# The Fan Art For "Star Wars: The Force Awakens" Is Staggeringly Beautiful
# Prediction: 1 for prompt: Is this title a clickbait: 'The Fan Art For "Star Wars: The Force Awakens" Is Staggeringly Beautiful'? Return 1 if yes, 0 if no.
# Return value: True
#
# Can you spot all NINE faces hidden in this painting? There's more to this tricky optical illusion than meets the eye
# Prediction: 1 for prompt: Is this title a clickbait: 'Can you spot all NINE faces hidden in this painting? There's more to this tricky optical illusion than meets the eye'? Return 1 if yes, 0 if no.
# Return value: True
#
# Geena Davis Talks About ‘The Exorcist’ and Women Onscreen - The New York Times
# Prediction: 0 for prompt: Is this title a clickbait: 'Geena Davis Talks About ‘The Exorcist’ and Women Onscreen - The New York Times'? Return 1 if yes, 0 if no.
# Return value: False
#
# President Trump Defends Bill O’Reilly Amid Sexual Harassment Claims
# Prediction: 1 for prompt: Is this title a clickbait: 'President Trump Defends Bill O’Reilly Amid Sexual Harassment Claims'? Return 1 if yes, 0 if no.
# Return value: True
#
# Sony Is Planning To Scrap The Kapil Sharma Show, Might Offer Sunil Grover His Own Show!
# Prediction: 1 for prompt: Is this title a clickbait: 'Sony Is Planning To Scrap The Kapil Sharma Show, Might Offer Sunil Grover His Own Show!'? Return 1 if yes, 0 if no.
# Return value: True
#
# Amber Rudd: Trump travel ban a 'propaganda opportunity' for Isis
# Prediction: 1 for prompt: Is this title a clickbait: 'Amber Rudd: Trump travel ban a 'propaganda opportunity' for Isis'? Return 1 if yes, 0 if no.
# Return value: True
#
# David Brock: Democrats ’in a Bad Situation,’ Hillary Loss ’Exposed the Lack of Democratic Power’ - Breitbart
# Prediction: 1 for prompt: Is this title a clickbait: 'David Brock: Democrats ’in a Bad Situation,’ Hillary Loss ’Exposed the Lack of Democratic Power’ - Breitbart'? Return 1 if yes, 0 if no.
# Return value: True
#
# 21 Scruffy Men That'll Get You All Hot And Bothered
# error when running LLM
#
# This Is How To Get A Pay Rise (Possibly)
# Prediction: 1 for prompt: Is this title a clickbait: 'This Is How To Get A Pay Rise (Possibly)'? Return 1 if yes, 0 if no.
# Return value: True
#
# Supreme Court deliberations on execution kept quiet
# Prediction: 1 for prompt: Is this title a clickbait: 'Supreme Court deliberations on execution kept quiet'? Return 1 if yes, 0 if no.
# Return value: True
#
# Uzbekistan is about to get its first new president in more than a quarter-century
# Prediction: 0 for prompt: Is this title a clickbait: 'Uzbekistan is about to get its first new president in more than a quarter-century'? Return 1 if yes, 0 if no.
# Return value: False
#
# DeMarcus Cousins Trade Rumors: Kings Shopping Star; Pelicans Interested
# Prediction: 1 for prompt: Is this title a clickbait: 'DeMarcus Cousins Trade Rumors: Kings Shopping Star; Pelicans Interested'? Return 1 if yes, 0 if no.
# Return value: True
#
# Philippine ministry asks Duterte to clarify military’s role in drug war
# Prediction: 0 for prompt: Is this title a clickbait: 'Philippine ministry asks Duterte to clarify military’s role in drug war'? Return 1 if yes, 0 if no.
# Return value: False
#
# Brexit is not the high point of democracy – it's the greatest fraud ever perpetrated in British politics
# Prediction: 1 for prompt: Is this title a clickbait: 'Brexit is not the high point of democracy – it's the greatest fraud ever perpetrated in British politics'? Return 1 if yes, 0 if no.
# Return value: True
#
# Oxford Dictionaries reveal word of the year as “clusterfuck”
# Prediction: 1 for prompt: Is this title a clickbait: 'Oxford Dictionaries reveal word of the year as “clusterfuck”'? Return 1 if yes, 0 if no.
# Return value: True
#
# WikiLeaks: Uttar Pradesh Chief Minister Mayawati sent jet to collect shoes
# Prediction: 1 for prompt: Is this title a clickbait: 'WikiLeaks: Uttar Pradesh Chief Minister Mayawati sent jet to collect shoes'? Return 1 if yes, 0 if no.
# Return value: True
#
# Yo, What's Happening Behind Cara Delevingne
# Prediction: 1 for prompt: Is this title a clickbait: 'Yo, What's Happening Behind Cara Delevingne'? Return 1 if yes, 0 if no.
# Return value: True
#
# West Africa Is Being Swallowed By The Sea
# Prediction: 1 for prompt: Is this title a clickbait: 'West Africa Is Being Swallowed By The Sea'? Return 1 if yes, 0 if no.
# Return value: True
#
# Four killed as missile strikes aircraft carrying Ivory Coast PM Guillaume Soro
# Prediction: 1 for prompt: Is this title a clickbait: 'Four killed as missile strikes aircraft carrying Ivory Coast PM Guillaume Soro'? Return 1 if yes, 0 if no.
# Return value: True
#
# 3.000 Yézidis toujours captifs de Daech
# Prediction: 1 for prompt: Is this title a clickbait: '3.000 Yézidis toujours captifs de Daech'? Return 1 if yes, 0 if no.
# Return value: True
#
# Crossword-Solving: A Search for Connections and Answers
# Prediction: 0 for prompt: Is this title a clickbait: 'Crossword-Solving: A Search for Connections and Answers '? Return 1 if yes, 0 if no.
# Return value: False
#
# Michigan Shows Trump Could Redraw Electoral Map vs. Clinton
# Prediction: 1 for prompt: Is this title a clickbait: 'Michigan Shows Trump Could Redraw Electoral Map vs. Clinton'? Return 1 if yes, 0 if no.
# Return value: True
#
# Which X-Men Character Are You Based On Your Zodiac Sign
# Prediction: 1 for prompt: Is this title a clickbait: 'Which X-Men Character Are You Based On Your Zodiac Sign'? Return 1 if yes, 0 if no.
# Return value: True
#
# Madonna Kisses Ariana Grande, Covers Britney Spears at Art Basel Miami Beach 2016
# Prediction: 1 for prompt: Is this title a clickbait: 'Madonna Kisses Ariana Grande, Covers Britney Spears at Art Basel Miami Beach 2016'? Return 1 if yes, 0 if no.
# Return value: True
#
# Teen Who Killed Self on Facebook Live Was Taunted by Mom: Report
# Prediction: 1 for prompt: Is this title a clickbait: 'Teen Who Killed Self on Facebook Live Was Taunted by Mom: Report'? Return 1 if yes, 0 if no.
# Return value: True
#
# Everyone Needs To Be Talking About Kesha
# Prediction: 1 for prompt: Is this title a clickbait: 'Everyone Needs To Be Talking About Kesha'? Return 1 if yes, 0 if no.
# Return value: True
#
# How Turned Off Are Voters? Check Out Tommy’s Diner - The New York Times
# Prediction: 1 for prompt: Is this title a clickbait: 'How Turned Off Are Voters? Check Out Tommy’s Diner - The New York Times'? Return 1 if yes, 0 if no.
# Return value: True
#
# Here's A Look Inside This Adult Coloring Book About The Beauty Of Natural Hair
# Prediction: 0 for prompt: Is this title a clickbait: 'Here's A Look Inside This Adult Coloring Book About The Beauty Of Natural Hair'? Return 1 if yes, 0 if no.
# Return value: False
#
# We Know Your Relationship Status Based On Your Opinions About 2015
# Prediction: 1 for prompt: Is this title a clickbait: 'We Know Your Relationship Status Based On Your Opinions About 2015'? Return 1 if yes, 0 if no.
# Return value: True
#
# A Day When Fashion and Tragedy Continue to Intersect - The New York Times
# Prediction: 1 for prompt: Is this title a clickbait: 'A Day When Fashion and Tragedy Continue to Intersect - The New York Times'? Return 1 if yes, 0 if no.
# Return value: True
#
# Are You In Your Freshman Or Senior Year
# Prediction: 0 for prompt: Is this title a clickbait: 'Are You In Your Freshman Or Senior Year'? Return 1 if yes, 0 if no.
# Return value: False
#
# Here's The Best Irish Bar In Every State
# Prediction: 1 for prompt: Is this title a clickbait: 'Here's The Best Irish Bar In Every State'? Return 1 if yes, 0 if no.
# Return value: True
#
# Can You Answer These Embarrassing Body Questions
# Prediction: 1 for prompt: Is this title a clickbait: 'Can You Answer These Embarrassing Body Questions'? Return 1 if yes, 0 if no.
# Return value: True
#
# 23 Tweets That Are Way Too Funny For People Who Wear Makeup
# Prediction: 1 for prompt: Is this title a clickbait: '23 Tweets That Are Way Too Funny For People Who Wear Makeup'? Return 1 if yes, 0 if no.
# Return value: True
#
# Free Wine Fountains and Other Bold Ways Wine Will Change in 2017
# Prediction: 1 for prompt: Is this title a clickbait: 'Free Wine Fountains and Other Bold Ways Wine Will Change in 2017'? Return 1 if yes, 0 if no.
# Return value: True
#
# Palme d’Or Goes to a Ken Loach Film at Cannes - The New York Times
# Prediction: 0 for prompt: Is this title a clickbait: 'Palme d’Or Goes to a Ken Loach Film at Cannes - The New York Times'? Return 1 if yes, 0 if no.
# Return value: False
#
# 27 Things You'll Only Understand If You're Slightly Obsessed With Nail Polish
# Prediction: 1 for prompt: Is this title a clickbait: '27 Things You'll Only Understand If You're Slightly Obsessed With Nail Polish'? Return 1 if yes, 0 if no.
# Return value: True
#
# Teenage cyclist hacked to death by masked gang on London estate
# Prediction: 1 for prompt: Is this title a clickbait: 'Teenage cyclist hacked to death by masked gang on London estate'? Return 1 if yes, 0 if no.
# Return value: True
#
# Big Pharma’s Martin Shkreli Suspended From Twitter - Breitbart
# Prediction: 1 for prompt: Is this title a clickbait: 'Big Pharma’s Martin Shkreli Suspended From Twitter - Breitbart'? Return 1 if yes, 0 if no.
# Return value: True
#
# 9 Painfully True SEX-Pectations Vs Reality
# error when running LLM
#
# The Fuckboy You're Shamelessly Attracted To Determines Your Zodiac
# Prediction: 1 for prompt: Is this title a clickbait: 'The Fuckboy You're Shamelessly Attracted To Determines Your Zodiac'? Return 1 if yes, 0 if no.
# Return value: True
#
# The end of the line for American long-distance trains?
# Prediction: 1 for prompt: Is this title a clickbait: 'The end of the line for American long-distance trains?'? Return 1 if yes, 0 if no.
# Return value: True
#
# WTO calls meeting on trade finance and economic crisis
# Prediction: 0 for prompt: Is this title a clickbait: 'WTO calls meeting on trade finance and economic crisis'? Return 1 if yes, 0 if no.
# Return value: False
#
# What It's Like Having PPD As A Black Woman
# Prediction: 1 for prompt: Is this title a clickbait: 'What It's Like Having PPD As A Black Woman'? Return 1 if yes, 0 if no.
# Return value: True
#
# Tom Fletcher Announced He's To Be A Dad Again In The Most Awesomely Amazing Way
# Prediction: 1 for prompt: Is this title a clickbait: 'Tom Fletcher Announced He's To Be A Dad Again In The Most Awesomely Amazing Way'? Return 1 if yes, 0 if no.
# Return value: True
#
# In Europe, Microsoft Fights Antitrust Charge Over Browser
# Prediction: 1 for prompt: Is this title a clickbait: 'In Europe, Microsoft Fights Antitrust Charge Over Browser'? Return 1 if yes, 0 if no.
# Return value: True
#
# 26 Quirks Americans Don’t Realize Are Super Weird
# Prediction: 1 for prompt: Is this title a clickbait: '26 Quirks Americans Don’t Realize Are Super Weird'? Return 1 if yes, 0 if no.
# Return value: True
#
# Watch the world's first ever monster truck front flip. You know you'll love it.
# Prediction: 1 for prompt: Is this title a clickbait: 'Watch the world's first ever monster truck front flip. You know you'll love it.'? Return 1 if yes, 0 if no.
# Return value: True
#
# China Working to Create Country’s Own Wikipedia Alternative - Breitbart
# Prediction: 1 for prompt: Is this title a clickbait: 'China Working to Create Country’s Own Wikipedia Alternative - Breitbart'? Return 1 if yes, 0 if no.
# Return value: True
#
# Lady Gaga, Marine Le Pen, Romania: Your Monday Briefing - The New York Times
# Prediction: 0 for prompt: Is this title a clickbait: 'Lady Gaga, Marine Le Pen, Romania: Your Monday Briefing - The New York Times'? Return 1 if yes, 0 if no.
# Return value: False
#
# These Memes Prove That Drake Can Always Dance On Beat
# Prediction: 1 for prompt: Is this title a clickbait: 'These Memes Prove That Drake Can Always Dance On Beat'? Return 1 if yes, 0 if no.
# Return value: True
#
# Lost tomb of 'Gladiator' real life Roman inspiration found
# Prediction: 1 for prompt: Is this title a clickbait: 'Lost tomb of 'Gladiator' real life Roman inspiration found'? Return 1 if yes, 0 if no.
# Return value: True
#
# The Original Doritos Did NOT Look Like Today's Doritos
# Prediction: 1 for prompt: Is this title a clickbait: 'The Original Doritos Did NOT Look Like Today's Doritos'? Return 1 if yes, 0 if no.
# Return value: True
#
# Are U.S. jobs vulnerable to workers with H-1B visas?
# Prediction: 1 for prompt: Is this title a clickbait: 'Are U.S. jobs vulnerable to workers with H-1B visas?'? Return 1 if yes, 0 if no.
# Return value: True
#
# Get Ready For Civil Unrest: Survey Finds That Most Americans Are Concerned About Election Violence
# Prediction: 1 for prompt: Is this title a clickbait: 'Get Ready For Civil Unrest: Survey Finds That Most Americans Are Concerned About Election Violence'? Return 1 if yes, 0 if no.
# Return value: True
#
# Goodbye, America's Next Top Model
# Prediction: 1 for prompt: Is this title a clickbait: 'Goodbye, America's Next Top Model'? Return 1 if yes, 0 if no.
# Return value: True
#
# В ответ на западные санкции русские перестали умирать
# Prediction: 1 for prompt: Is this title a clickbait: 'В ответ на западные санкции русские перестали умирать'? Return 1 if yes, 0 if no.
# Return value: True
#
# Nadal Masters Clay  by Being Consistent and Relentless
# Prediction: 0 for prompt: Is this title a clickbait: 'Nadal Masters Clay  by Being Consistent and Relentless'? Return 1 if yes, 0 if no.
# Return value: False
#
# Ex-State Staffer Who Advocated Spying On Trump Boasted ’Getting Winks From Inside’ Obama Admin
# Prediction: 1 for prompt: Is this title a clickbait: 'Ex-State Staffer Who Advocated Spying On Trump Boasted ’Getting Winks From Inside’ Obama Admin'? Return 1 if yes, 0 if no.
# Return value: True
#
# It Looks Like Paris And Doyle Are Still Together In The "Gilmore Girls" Revival
# Prediction: 1 for prompt: Is this title a clickbait: 'It Looks Like Paris And Doyle Are Still Together In The "Gilmore Girls" Revival'? Return 1 if yes, 0 if no.
# Return value: True
#
# Hundreds of people gather in support of Mikhail Khodorkovsky
# Prediction: 0 for prompt: Is this title a clickbait: 'Hundreds of people gather in support of Mikhail Khodorkovsky'? Return 1 if yes, 0 if no.
# Return value: False
#
# Arrest warrant issued for Tom DeLay
# Prediction: 1 for prompt: Is this title a clickbait: 'Arrest warrant issued for Tom DeLay'? Return 1 if yes, 0 if no.
# Return value: True
#
# Dutch Men Hold Hands in Solidarity With Attacked Gay Couple - The New York Times
# Prediction: 0 for prompt: Is this title a clickbait: 'Dutch Men Hold Hands in Solidarity With Attacked Gay Couple - The New York Times'? Return 1 if yes, 0 if no.
# Return value: False
#
# Hebrew may be world's oldest alphabet
# Prediction: 1 for prompt: Is this title a clickbait: 'Hebrew may be world's oldest alphabet '? Return 1 if yes, 0 if no.
# Return value: True
#
# Mission Accomplished: Consumer Sentiment Plummets After Comey Hearing - Breitbart
# Prediction: 1 for prompt: Is this title a clickbait: 'Mission Accomplished: Consumer Sentiment Plummets After Comey Hearing - Breitbart'? Return 1 if yes, 0 if no.
# Return value: True
#
# ...
# Return value: True
#
# Here Are The Six Guys You Have Inevitably Danced With At A Club
# error when running LLM
#
# The Alignment Between These Ancient Sites Will Blow Your Mind
# Prediction: 1 for prompt: Is this title a clickbait: 'The Alignment Between These Ancient Sites Will Blow Your Mind'? Return 1 if yes, 0 if no.
# Return value: True
#
# The Conscious Resistance (Feat. Derrick Broze)
# Prediction: 1 for prompt: Is this title a clickbait: 'The Conscious Resistance (Feat. Derrick Broze)'? Return 1 if yes, 0 if no.
# Return value: True
#
# Seven figure pocket money, sneering at 'peasants' and destroying possessions for fun: The Rich Kids of Instagram's most outrageous moments of 2016 revealed
# Prediction: 1 for prompt: Is this title a clickbait: 'Seven figure pocket money, sneering at 'peasants' and destroying possessions for fun: The Rich Kids of Instagram's most outrageous moments of 2016 revealed'? Return 1 if yes, 0 if no.
# Return value: True
#
# ’Never Trump’ presidential candidate: Sources have told me Trump ’hides in his apartment’ and they’re ’frustrated’
# Prediction: 1 for prompt: Is this title a clickbait: '’Never Trump’ presidential candidate: Sources have told me Trump ’hides in his apartment’ and they’re ’frustrated’'? Return 1 if yes, 0 if no.
# Return value: True
#
# Mexican billionaire denies buying Honda Formula One team
# Prediction: 0 for prompt: Is this title a clickbait: 'Mexican billionaire denies buying Honda Formula One team'? Return 1 if yes, 0 if no.
# Return value: False
#
# Paul Ryan says he's seen "no evidence" for President Trump's unverified illegal ballots claim
# Prediction: 0 for prompt: Is this title a clickbait: 'Paul Ryan says he's seen "no evidence" for President Trump's unverified illegal ballots claim'? Return 1 if yes, 0 if no.
# Return value: False
#
# A royal embrace! Chic Princess Charlene cuddles daughter Gabriella, 2, as the Monaco royal family enjoy a day at a charity rugby tournament
# Prediction: 1 for prompt: Is this title a clickbait: 'A royal embrace! Chic Princess Charlene cuddles daughter Gabriella, 2, as the Monaco royal family enjoy a day at a charity rugby tournament'? Return 1 if yes, 0 if no.
# Return value: True
#
# Report: FBI Didn’t Ask Hillary Aides To Hand Over Devices While Hillary Was Secretary of State
# Prediction: 1 for prompt: Is this title a clickbait: 'Report: FBI Didn’t Ask Hillary Aides To Hand Over Devices While Hillary Was Secretary of State'? Return 1 if yes, 0 if no.
# Return value: True
#
# WHAT HAPPENED? In 2014, Quebec tried to pass a Charter that would have banned all religious attire in public, specifically to prevent Muslim women from hiding their faces
# Prediction: 1 for prompt: Is this title a clickbait: 'WHAT HAPPENED? In 2014, Quebec tried to pass a Charter that would have banned all religious attire in public, specifically to prevent Muslim women from hiding their faces'? Return 1 if yes, 0 if no.
# Return value: True
#
# 12 Ways "Today's Special" Was The Most WTF Kids' Show Ever
# Prediction: 1 for prompt: Is this title a clickbait: '12 Ways "Today's Special" Was The Most WTF Kids' Show Ever'? Return 1 if yes, 0 if no.
# Return value: True
#
# ‘I’ve Got Thick Skin’: We Talk to the Pro-Trump Mayor Who Was Running From Us - The New York Times
# Prediction: 1 for prompt: Is this title a clickbait: '‘I’ve Got Thick Skin’: We Talk to the Pro-Trump Mayor Who Was Running From Us - The New York Times'? Return 1 if yes, 0 if no.
# Return value: True
#
# 27 School Supplies That Will Give You Intense Elementary School Flashbacks
# Prediction: 1 for prompt: Is this title a clickbait: '27 School Supplies That Will Give You Intense Elementary School Flashbacks'? Return 1 if yes, 0 if no.
# Return value: True
#
# The Definitive Ranking Of Ellie Goulding's Music Videos
# Prediction: 1 for prompt: Is this title a clickbait: 'The Definitive Ranking Of Ellie Goulding's Music Videos'? Return 1 if yes, 0 if no.
# Return value: True
#
# Senior diplomat criticizes U.S. policy in Iraq
# Prediction: 1 for prompt: Is this title a clickbait: 'Senior diplomat criticizes U.S. policy in Iraq'? Return 1 if yes, 0 if no.
# Return value: True
#
# Actor, Trump Supporter Antonio Sabato Jr. Running For Congress in California
# Prediction: 1 for prompt: Is this title a clickbait: 'Actor, Trump Supporter Antonio Sabato Jr. Running For Congress in California'? Return 1 if yes, 0 if no.
# Return value: True
#
# You Will Never Think Of Pizza The Same Way After Trying This Dip
# Prediction: 1 for prompt: Is this title a clickbait: 'You Will Never Think Of Pizza The Same Way After Trying This Dip'? Return 1 if yes, 0 if no.
# Return value: True
#
# Can We Guess What You Hate Most Based On How You Swear
# Prediction: 1 for prompt: Is this title a clickbait: 'Can We Guess What You Hate Most Based On How You Swear'? Return 1 if yes, 0 if no.
# Return value: True
#
# 400 Mexican Soldiers Headed to Border in Hunt for Gulf Cartel Boss ’Comandante Toro’
# Prediction: 0 for prompt: Is this title a clickbait: '400 Mexican Soldiers Headed to Border in Hunt for Gulf Cartel Boss ’Comandante Toro’'? Return 1 if yes, 0 if no.
# Return value: False
#
# What's The Most Annoying Misconception About Sororities
# Prediction: 1 for prompt: Is this title a clickbait: 'What's The Most Annoying Misconception About Sororities'? Return 1 if yes, 0 if no.
# Return value: True
#
# Nigeria Central Bank Hits Out at ‘Unpatriotic’ Policy Critics
# Prediction: 1 for prompt: Is this title a clickbait: 'Nigeria Central Bank Hits Out at ‘Unpatriotic’ Policy Critics'? Return 1 if yes, 0 if no.
# Return value: True
#
# How Well Do You Remember The Names Of These '00 Disney Online Games
# Prediction: 1 for prompt: Is this title a clickbait: 'How Well Do You Remember The Names Of These '00 Disney Online Games'? Return 1 if yes, 0 if no.
# Return value: True
#
# Theo 'rape' case fuels clashes with police in Paris area
# Prediction: 1 for prompt: Is this title a clickbait: 'Theo 'rape' case fuels clashes with police in Paris area'? Return 1 if yes, 0 if no.
# Return value: True
#
# App Smart | Instant Photo Collages - Video - NYTimes.com
# Prediction: 1 for prompt: Is this title a clickbait: 'App Smart | Instant Photo Collages - Video - NYTimes.com'? Return 1 if yes, 0 if no.
# Return value: True
#
# Kyrie Irving Blessed Victor Cruz With This Unreleased Nike Kyrie 3
# Prediction: 1 for prompt: Is this title a clickbait: 'Kyrie Irving Blessed Victor Cruz With This Unreleased Nike Kyrie 3'? Return 1 if yes, 0 if no.
# Return value: True
#
# Re: What Is The Best Place To Live In The United States To Prepare For The Coming Economic Collapse?
# Prediction: 1 for prompt: Is this title a clickbait: 'Re: What Is The Best Place To Live In The United States To Prepare For The Coming Economic Collapse?'? Return 1 if yes, 0 if no.
# Return value: True
#
# Red wine ingredient may improve health of obese men
# Prediction: 1 for prompt: Is this title a clickbait: 'Red wine ingredient may improve health of obese men'? Return 1 if yes, 0 if no.
# Return value: True
#
# House Intelligence Chair Nunes: Surveillance of Trump Transition Team ’Incidentally Collected’ - Breitbart
# Prediction: 1 for prompt: Is this title a clickbait: 'House Intelligence Chair Nunes: Surveillance of Trump Transition Team ’Incidentally Collected’ - Breitbart'? Return 1 if yes, 0 if no.
# Return value: True
#
# Paul Krugman’s Facebook Friends Excitedly Posting About New Article He Got Published In ‘The New York Times’ - The Onion - America's Finest News Source
# Prediction: 1 for prompt: Is this title a clickbait: 'Paul Krugman’s Facebook Friends Excitedly Posting About New Article He Got Published In ‘The New York Times’ - The Onion - America's Finest News Source'? Return 1 if yes, 0 if no.
# Return value: True
#
# Trump Appointment of Gorsuch an Epic 100-Day Success - Breitbart
# Prediction: 1 for prompt: Is this title a clickbait: 'Trump Appointment of Gorsuch an Epic 100-Day Success - Breitbart'? Return 1 if yes, 0 if no.
# Return value: True
#
# Chinese City Bolsters Scant Consumer Spending With Free Vouchers
# Prediction: 1 for prompt: Is this title a clickbait: 'Chinese City Bolsters Scant Consumer Spending With Free Vouchers'? Return 1 if yes, 0 if no.
# Return value: True
#
# Debate: Washington's Syria policy
# Prediction: 0 for prompt: Is this title a clickbait: 'Debate: Washington's Syria policy'? Return 1 if yes, 0 if no.
# Return value: False
#
# Big Show: The giant with the six-pack
# Prediction: 1 for prompt: Is this title a clickbait: 'Big Show: The giant with the six-pack'? Return 1 if yes, 0 if no.
# Return value: True
#
# Killing of an Oregon wildlife refuge occupier has re-energized protesters
# Prediction: 1 for prompt: Is this title a clickbait: 'Killing of an Oregon wildlife refuge occupier has re-energized protesters'? Return 1 if yes, 0 if no.
# Return value: True
#
# British man dies five days after wife in honeymoon shooting
# Prediction: 1 for prompt: Is this title a clickbait: 'British man dies five days after wife in honeymoon shooting'? Return 1 if yes, 0 if no.
# Return value: True
#
# Even Republican Christian Moms in Texas Are Fighting for Medical Weed
# Prediction: 1 for prompt: Is this title a clickbait: 'Even Republican Christian Moms in Texas Are Fighting for Medical Weed'? Return 1 if yes, 0 if no.
# Return value: True
#
# As E.C.B. Charts Economic Course, Politics Complicate the Picture - The New York Times
# Prediction: 0 for prompt: Is this title a clickbait: 'As E.C.B. Charts Economic Course, Politics Complicate the Picture - The New York Times'? Return 1 if yes, 0 if no.
# Return value: False
#
# Politician denies claims he smoked cannabis while ambassador
# Prediction: 1 for prompt: Is this title a clickbait: 'Politician denies claims he smoked cannabis while ambassador'? Return 1 if yes, 0 if no.
# Return value: True
#
# Anthony Bourdain bashes fellow ‘privileged Eastern liberals’ for making Trump win possible
# Prediction: 1 for prompt: Is this title a clickbait: 'Anthony Bourdain bashes fellow ‘privileged Eastern liberals’ for making Trump win possible'? Return 1 if yes, 0 if no.
# Return value: True
#
# The Dark Arts Of Bradford Cox
# Prediction: 1 for prompt: Is this title a clickbait: 'The Dark Arts Of Bradford Cox'? Return 1 if yes, 0 if no.
# Return value: True
#
# Former Illinois governor Blagojevich asks US Supreme Court to delay corruption trial, prosecutors to respond by Friday
# Prediction: 0 for prompt: Is this title a clickbait: 'Former Illinois governor Blagojevich asks US Supreme Court to delay corruption trial, prosecutors to respond by Friday'? Return 1 if yes, 0 if no.
# Return value: False
#
# ‘Westworld’ Season 1, Episode 6: The Tipping Point - The New York Times
# Prediction: 0 for prompt: Is this title a clickbait: '‘Westworld’ Season 1, Episode 6: The Tipping Point - The New York Times'? Return 1 if yes, 0 if no.
# Return value: False
#
# A Guy Sent Debra Messing A Dick Pic So She Shared It With Her 257,000 Twitter Followers
# error when running LLM
#
# Little League Puts a Special Focus on Urban Programs
# Prediction: 0 for prompt: Is this title a clickbait: 'Little League Puts a Special Focus on Urban Programs'? Return 1 if yes, 0 if no.
# Return value: False
#
# Debbie Reynolds, Eddie Fisher, and Elizabeth Taylor: Inside Hollywood’s First Love Triangle
# Prediction: 1 for prompt: Is this title a clickbait: 'Debbie Reynolds, Eddie Fisher, and Elizabeth Taylor: Inside Hollywood’s First Love Triangle'? Return 1 if yes, 0 if no.
# Return value: True
#
# Russia: The West Is Trapped in Its Own ‘Propaganda-Created World’
# Prediction: 1 for prompt: Is this title a clickbait: 'Russia: The West Is Trapped in Its Own ‘Propaganda-Created World’'? Return 1 if yes, 0 if no.
# Return value: True
#
# New guidelines outline how to handle back pain
# Prediction: 0 for prompt: Is this title a clickbait: 'New guidelines outline how to handle back pain'? Return 1 if yes, 0 if no.
# Return value: False
#
# 11 Reasons Why You Probably Shouldn't Let Santa Break Into Your Home This Christmas
# Prediction: 1 for prompt: Is this title a clickbait: '11 Reasons Why You Probably Shouldn't Let Santa Break Into Your Home This Christmas'? Return 1 if yes, 0 if no.
# Return value: True
#
# Inspiring America: 100 Years of Girl Scout Cookies
# Prediction: 0 for prompt: Is this title a clickbait: 'Inspiring America: 100 Years of Girl Scout Cookies'? Return 1 if yes, 0 if no.
# Return value: False
#
# Britain Looks to Expand Broadband and Limit Piracy
# Prediction: 0 for prompt: Is this title a clickbait: 'Britain Looks to Expand Broadband and Limit Piracy'? Return 1 if yes, 0 if no.
# Return value: False
#
# The Green Toy Soldiers From Your Childhood Now Come In Baller Yoga Poses A
# Prediction: 1 for prompt: Is this title a clickbait: 'The Green Toy Soldiers From Your Childhood Now Come In Baller Yoga Poses A'? Return 1 if yes, 0 if no.
# Return value: True
#
# Stash Some Cash -- You're One Surprise Away From Going Broke
# Prediction: 1 for prompt: Is this title a clickbait: 'Stash Some Cash -- You're One Surprise Away From Going Broke'? Return 1 if yes, 0 if no.
# Return value: True
#
# Cleveland Man Suspected In Facebook Video Killing Found Dead
# Prediction: 1 for prompt: Is this title a clickbait: 'Cleveland Man Suspected In Facebook Video Killing Found Dead'? Return 1 if yes, 0 if no.
# Return value: True
#
# Pope Francis Notes Azerbaijan’s Religious Tolerance, Not Rights Abuses - The New York Times
# Prediction: 1 for prompt: Is this title a clickbait: 'Pope Francis Notes Azerbaijan’s Religious Tolerance, Not Rights Abuses - The New York Times'? Return 1 if yes, 0 if no.
# Return value: True
#
# New Solar Panels Pull Drinking Water From The Air Because Clean Water Is A Human Right
# Prediction: 1 for prompt: Is this title a clickbait: 'New Solar Panels Pull Drinking Water From The Air Because Clean Water Is A Human Right'? Return 1 if yes, 0 if no.
# Return value: True
#
# A Transformational November of Taking a Stand
# Prediction: 1 for prompt: Is this title a clickbait: 'A Transformational November of Taking a Stand'? Return 1 if yes, 0 if no.
# Return value: True
#
# Taylor Swift's New Video Has Loads Of Callbacks To Harry Styles
# Prediction: 1 for prompt: Is this title a clickbait: 'Taylor Swift's New Video Has Loads Of Callbacks To Harry Styles'? Return 1 if yes, 0 if no.
# Return value: True
#
# Bruce Highway crash: Fatal four-vehicle collision closes major road near Maryborough
# Prediction: 0 for prompt: Is this title a clickbait: 'Bruce Highway crash: Fatal four-vehicle collision closes major road near Maryborough'? Return 1 if yes, 0 if no.
# Return value: False
#
# Dem Sen Menendez: Trump ’Great Wall of Hate’ a Waste of $20 Billion - Breitbart
# Prediction: 1 for prompt: Is this title a clickbait: 'Dem Sen Menendez: Trump ’Great Wall of Hate’ a Waste of $20 Billion - Breitbart'? Return 1 if yes, 0 if no.
# Return value: True
#
# 21 Times Blue Ivy's Hair Stunted On Toddlers Everywhere
# Prediction: 1 for prompt: Is this title a clickbait: '21 Times Blue Ivy's Hair Stunted On Toddlers Everywhere'? Return 1 if yes, 0 if no.
# Return value: True
#
# Workplace reform campaign most expensive in Australian history
# Prediction: 1 for prompt: Is this title a clickbait: 'Workplace reform campaign most expensive in Australian history'? Return 1 if yes, 0 if no.
# Return value: True
#
# US Secret Service Struggles To Find Recruits Who Haven’t Used Adderall
# Prediction: 1 for prompt: Is this title a clickbait: 'US Secret Service Struggles To Find Recruits Who Haven’t Used Adderall'? Return 1 if yes, 0 if no.
# Return value: True
#
# Time to Unravel the Knot of Credit-Default Swaps
# Prediction: 1 for prompt: Is this title a clickbait: 'Time to Unravel the Knot of Credit-Default Swaps'? Return 1 if yes, 0 if no.
# Return value: True
#
# Which "Shameless" Character Are You Based On Your Zodiac Sign
# Prediction: 1 for prompt: Is this title a clickbait: 'Which "Shameless" Character Are You Based On Your Zodiac Sign'? Return 1 if yes, 0 if no.
# Return value: True
#
# [WATCH] 13-Year-Old Girl BREAKS THE INTERNET With Pro-Trump Speech
# Prediction: 1 for prompt: Is this title a clickbait: '[WATCH] 13-Year-Old Girl BREAKS THE INTERNET With Pro-Trump Speech'? Return 1 if yes, 0 if no.
# Return value: True

# %%
df
# Out:
#                                                  title  is_clickbait  llm_pred
# 0                     Earthquake shakes western Mexico             0       0.0
# 1    Brandon Marshall receives threatening letter; ...             0       1.0
# 2    Visa Ban Amended to Allow Iraqi Interpreters I...             0       0.0
# 3    Star Wars: What do fans make of the trailer fo...             1       1.0
# 4          61 businesses Trump has targeted on Twitter             1       1.0
# ..                                                 ...           ...       ...
# 995  Workplace reform campaign most expensive in Au...             0       1.0
# 996  US Secret Service Struggles To Find Recruits W...             1       1.0
# 997   Time to Unravel the Knot of Credit-Default Swaps             0       1.0
# 998  Which "Shameless" Character Are You Based On Y...             1       1.0
# 999  [WATCH] 13-Year-Old Girl BREAKS THE INTERNET W...             1       1.0
#
# [1000 rows x 3 columns]

# %%
from sklearn.metrics import roc_auc_score, f1_score

df.dropna(inplace=True)

print(f"ROC AUC: {roc_auc_score(df['is_clickbait'], df['llm_pred'])}")
print(f"F1 Score: {f1_score(df['is_clickbait'], df['llm_pred'] > 0.5)}")
# Out:
# ROC AUC: 0.6614309603440038
# F1 Score: 0.7274247491638797

# %%
# plot ROC curve
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(df['is_clickbait'], df['llm_pred'])
# add random line
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# make plot have white background
plt.gca().set_facecolor('w')

plt.title('ROC Curve')
